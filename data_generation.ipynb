# %%
import numpy as np
import os
from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels

from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %% [markdown]
# ### Create h5 dataset

# %%
#################################################################################
# # # # # # # # # # #        DATA PREPARATION          # # # # # # # # # # # # #
#################################################################################
#https://github.com/pierluigiferrari/data_generator_object_detection_2d

# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

train_dataset = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset   = DataGenerator(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.

# TODO: Set the paths to the datasets here.

data_path = '/media/auv/DATA/Data/Fish_Training_Data/'

# The directories that contain the images.
pacstorm_training_images_dir      = os.path.join(data_path , "Training/Pacstorm", "images")
pacstorm_validation_images_dir      =  os.path.join(data_path , "Validation/Pacstorm", "images")
pmfs_training_images_dir      =  os.path.join(data_path , "Training/PMFS", "images")
pmfs_validation_images_dir      =  os.path.join(data_path , "Validation/PMFS", "images")

# The directories that contain the annotations.
pacstorm_training_annotations_dir      = os.path.join(data_path , "Training", "Pacstorm_Annotations")
pacstorm_validation_annotations_dir      = os.path.join(data_path , "Validation", "Pacstorm_Annotations")
pmfs_training_annotations_dir      =  os.path.join(data_path , "Training", "PMFS_Annotations")
pmfs_validation_annotations_dir      =  os.path.join(data_path , "Validation", "PMFS_Annotations")

# The paths to the image sets.
pacstorm_training_image_set_filename    =  os.path.join(data_path , "Training/Pacstorm",'images.txt')
pmfs_training_image_set_filename    =  os.path.join(data_path , "Training/PMFS",'images.txt')
pacstorm_validation_image_set_filename    =  os.path.join(data_path , "Validation/Pacstorm",'images.txt')
pmfs_validation_image_set_filename    =  os.path.join(data_path , "Validation/PMFS",'images.txt')

# TODO: Specify name of the classes for which the data is being prepared
# The XML parser needs to now what object class names to look for and in which order to map them to integers.
classes = ['background','fish', 'starfish','sponge']
# Out:
# here
# done

# %%
# TODO: Set include_classes bases on the number of classes

train_dataset.parse_xml(images_dirs=[pacstorm_training_images_dir,
                                     pmfs_training_images_dir],
                        image_set_filenames=[pacstorm_training_image_set_filename,
                                             pmfs_training_image_set_filename],
                        annotations_dirs=[pacstorm_training_annotations_dir,
                                          pmfs_training_annotations_dir],
                        classes=classes,
                        include_classes=[0,1,2],
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[pacstorm_validation_images_dir, 
                                   pmfs_validation_images_dir],
                      image_set_filenames=[pacstorm_validation_image_set_filename, 
                                           pmfs_validation_image_set_filename],
                      annotations_dirs=[pacstorm_validation_annotations_dir, 
                                       pmfs_validation_annotations_dir],
                      classes=classes,
                      include_classes=[0,1,2],
                      exclude_truncated=False,
                      exclude_difficult=True,
                      ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

train_dataset.create_hdf5_dataset(file_path='dataset_fish_train.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='dataset_fish_val.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)
# Out:
# Processing image set 'images.txt':   0%|          | 0/1330 [00:00<?, ?it/s]
#
#
# Processing image set 'images.txt':   4%|▎         | 47/1330 [00:00<00:02, 459.21it/s]
#
#
# Processing image set 'images.txt':   8%|▊         | 112/1330 [00:00<00:02, 503.05it/s]
#
#
# Processing image set 'images.txt':  12%|█▏        | 163/1330 [00:00<00:02, 505.07it/s]
#
#
# Processing image set 'images.txt':  17%|█▋        | 230/1330 [00:00<00:02, 543.92it/s]
#
#
# Processing image set 'images.txt':  23%|██▎       | 307/1330 [00:00<00:01, 594.11it/s]
#
#
# Processing image set 'images.txt':  29%|██▉       | 385/1330 [00:00<00:01, 639.36it/s]
#
#
# Processing image set 'images.txt':  35%|███▍      | 465/1330 [00:00<00:01, 679.90it/s]
#
#
# Processing image set 'images.txt':  41%|████      | 540/1330 [00:00<00:01, 699.40it/s]
#
#
# Processing image set 'images.txt':  46%|████▌     | 612/1330 [00:00<00:01, 698.94it/s]
#
#
# Processing image set 'images.txt':  51%|█████▏    | 682/1330 [00:01<00:00, 661.80it/s]
#
#
# Processing image set 'images.txt':  56%|█████▋    | 749/1330 [00:01<00:00, 647.78it/s]
#
#
# Processing image set 'images.txt':  61%|██████    | 814/1330 [00:01<00:00, 630.12it/s]
#
#
# Processing image set 'images.txt':  66%|██████▌   | 878/1330 [00:01<00:00, 552.25it/s]
#
#
# Processing image set 'images.txt':  72%|███████▏  | 952/1330 [00:01<00:00, 597.20it/s]
#
#
# Processing image set 'images.txt':  77%|███████▋  | 1030/1330 [00:01<00:00, 641.34it/s]
#
#
# Processing image set 'images.txt':  83%|████████▎ | 1107/1330 [00:01<00:00, 674.30it/s]
#
#
# Processing image set 'images.txt':  89%|████████▉ | 1185/1330 [00:01<00:00, 701.12it/s]
#
#
# Processing image set 'images.txt':  95%|█████████▍| 1263/1330 [00:01<00:00, 721.21it/s]
#
#
# Processing image set 'images.txt': 100%|██████████| 1330/1330 [00:02<00:00, 663.99it/s]
#
#
# Processing image set 'images.txt':   0%|          | 0/2266 [00:00<?, ?it/s]
#
#
# Processing image set 'images.txt':   3%|▎         | 72/2266 [00:00<00:03, 713.51it/s]
#
#
# Processing image set 'images.txt':   6%|▋         | 142/2266 [00:00<00:03, 707.46it/s]
#
#
# Processing image set 'images.txt':   8%|▊         | 192/2266 [00:00<00:03, 627.48it/s]
#
#
# Processing image set 'images.txt':  10%|█         | 233/2266 [00:00<00:03, 535.34it/s]
#
#
# Processing image set 'images.txt':  13%|█▎        | 296/2266 [00:00<00:03, 560.38it/s]
#
#
# Processing image set 'images.txt':  17%|█▋        | 377/2266 [00:00<00:03, 617.10it/s]
#
#
# Processing image set 'images.txt':  20%|██        | 454/2266 [00:00<00:02, 655.44it/s]
#
#
# Processing image set 'images.txt':  23%|██▎       | 517/2266 [00:00<00:03, 545.73it/s]
#
#
# Processing image set 'images.txt':  25%|██▌       | 573/2266 [00:00<00:03, 532.88it/s]
#
#
# Processing image set 'images.txt':  28%|██▊       | 628/2266 [00:01<00:03, 489.77it/s]
#
#
# Processing image set 'images.txt':  30%|███       | 686/2266 [00:01<00:03, 509.95it/s]
#
#
# Processing image set 'images.txt':  33%|███▎      | 754/2266 [00:01<00:02, 549.84it/s]
#
#
# Processing image set 'images.txt':  36%|███▋      | 826/2266 [00:01<00:02, 590.90it/s]
#
#
# Processing image set 'images.txt':  39%|███▉      | 888/2266 [00:01<00:02, 542.71it/s]
#
#
# Processing image set 'images.txt':  42%|████▏     | 949/2266 [00:01<00:02, 560.93it/s]
#
#
# Processing image set 'images.txt':  45%|████▍     | 1014/2266 [00:01<00:02, 584.17it/s]
#
#
# Processing image set 'images.txt':  49%|████▊     | 1100/2266 [00:01<00:01, 646.19it/s]
#
#
# Processing image set 'images.txt':  52%|█████▏    | 1187/2266 [00:01<00:01, 697.21it/s]
#
#
# Processing image set 'images.txt':  56%|█████▋    | 1277/2266 [00:02<00:01, 747.72it/s]
#
#
# Processing image set 'images.txt':  60%|█████▉    | 1356/2266 [00:02<00:01, 457.96it/s]
#
#
# Processing image set 'images.txt':  63%|██████▎   | 1418/2266 [00:02<00:01, 449.31it/s]
#
#
# Processing image set 'images.txt':  65%|██████▌   | 1476/2266 [00:02<00:01, 481.12it/s]
#
#
# Processing image set 'images.txt':  69%|██████▉   | 1565/2266 [00:02<00:01, 557.25it/s]
#
#
# Processing image set 'images.txt':  73%|███████▎  | 1651/2266 [00:02<00:00, 621.75it/s]
#
#
# Processing image set 'images.txt':  77%|███████▋  | 1734/2266 [00:02<00:00, 671.76it/s]
#
#
# Processing image set 'images.txt':  80%|███████▉  | 1810/2266 [00:03<00:00, 563.18it/s]
#
#
# Processing image set 'images.txt':  83%|████████▎ | 1875/2266 [00:03<00:00, 510.47it/s]
#
#
# Processing image set 'images.txt':  87%|████████▋ | 1963/2266 [00:03<00:00, 583.78it/s]
#
#
# Processing image set 'images.txt':  92%|█████████▏| 2089/2266 [00:03<00:00, 695.33it/s]
#
#
# Processing image set 'images.txt':  98%|█████████▊| 2210/2266 [00:03<00:00, 796.76it/s]
#
#
# Processing image set 'images.txt': 100%|██████████| 2266/2266 [00:03<00:00, 626.14it/s]
#
#
# Processing image set 'images.txt':   0%|          | 0/380 [00:00<?, ?it/s]
#
#
# Processing image set 'images.txt':  22%|██▏       | 83/380 [00:00<00:00, 824.16it/s]
#
#
# Processing image set 'images.txt':  42%|████▏     | 158/380 [00:00<00:00, 797.88it/s]
#
#
# Processing image set 'images.txt':  63%|██████▎   | 238/380 [00:00<00:00, 796.55it/s]
#
#
# Processing image set 'images.txt':  84%|████████▍ | 320/380 [00:00<00:00, 799.64it/s]
#
#
# Processing image set 'images.txt': 100%|██████████| 380/380 [00:00<00:00, 793.95it/s]
#
#
# Processing image set 'images.txt':   0%|          | 0/647 [00:00<?, ?it/s]
#
#
# Processing image set 'images.txt':  15%|█▍        | 95/647 [00:00<00:00, 949.29it/s]
#
#
# Processing image set 'images.txt':  28%|██▊       | 183/647 [00:00<00:00, 923.97it/s]
#
#
# Processing image set 'images.txt':  42%|████▏     | 273/647 [00:00<00:00, 915.52it/s]
#
#
# Processing image set 'images.txt':  57%|█████▋    | 368/647 [00:00<00:00, 925.50it/s]
#
#
# Processing image set 'images.txt':  71%|███████▏  | 462/647 [00:00<00:00, 929.22it/s]
#
#
# Processing image set 'images.txt':  85%|████████▌ | 553/647 [00:00<00:00, 922.28it/s]
#
#
# Processing image set 'images.txt':  98%|█████████▊| 635/647 [00:00<00:00, 870.50it/s]
#
#
# Processing image set 'images.txt': 100%|██████████| 647/647 [00:00<00:00, 890.24it/s]
#
#
# Creating HDF5 dataset:   0%|          | 0/3596 [00:00<?, ?it/s]
#
#
# Creating HDF5 dataset:   0%|          | 2/3596 [00:00<05:33, 10.78it/s]
#
#
# Creating HDF5 dataset:   0%|          | 3/3596 [00:00<05:51, 10.22it/s]
#
#
# Creating HDF5 dataset:   0%|          | 5/3596 [00:00<05:49, 10.29it/s]
#
#
# Creating HDF5 dataset:   0%|          | 7/3596 [00:00<05:38, 10.62it/s]
#
#
# Creating HDF5 dataset:   0%|          | 9/3596 [00:00<05:18, 11.26it/s]
#
#
# Creating HDF5 dataset:   0%|          | 11/3596 [00:00<05:18, 11.24it/s]
#
#
# Creating HDF5 dataset:   0%|          | 13/3596 [00:01<05:07, 11.66it/s]
#
#
# Creating HDF5 dataset:   0%|          | 15/3596 [00:01<05:03, 11.79it/s]
#
#
# Creating HDF5 dataset:   0%|          | 17/3596 [00:01<05:01, 11.87it/s]
#
#
# Creating HDF5 dataset:   1%|          | 19/3596 [00:01<04:56, 12.06it/s]
#
#
# Creating HDF5 dataset:   1%|          | 21/3596 [00:01<04:47, 12.42it/s]
#
#
# Creating HDF5 dataset:   1%|          | 23/3596 [00:01<04:54, 12.15it/s]
#
#
# Creating HDF5 dataset:   1%|          | 25/3596 [00:02<04:53, 12.17it/s]
#
#
# Creating HDF5 dataset:   1%|          | 27/3596 [00:02<04:50, 12.27it/s]
#
#
# Creating HDF5 dataset:   1%|          | 29/3596 [00:02<04:52, 12.19it/s]
#
#
# Creating HDF5 dataset:   1%|          | 31/3596 [00:02<04:50, 12.27it/s]
#
#
# Creating HDF5 dataset:   1%|          | 33/3596 [00:02<04:52, 12.17it/s]
#
#
# Creating HDF5 dataset:   1%|          | 35/3596 [00:02<05:01, 11.81it/s]
#
#
# Creating HDF5 dataset:   1%|          | 37/3596 [00:03<04:58, 11.93it/s]
# Creating HDF5 dataset:   1%|          | 39/3596 [00:03<04:54, 12.06it/s]
#
#
# Creating HDF5 dataset:   1%|          | 41/3596 [00:03<04:58, 11.90it/s]
#
#
# Creating HDF5 dataset:   1%|          | 43/3596 [00:03<04:59, 11.87it/s]
#
#
# Creating HDF5 dataset:   1%|▏         | 45/3596 [00:03<04:58, 11.91it/s]
#
#
# Creating HDF5 dataset:   1%|▏         | 47/3596 [00:03<05:04, 11.67it/s]
#
#
# Creating HDF5 dataset:   1%|▏         | 49/3596 [00:04<04:55, 12.00it/s]
#
#
# Creating HDF5 dataset:   1%|▏         | 51/3596 [00:04<04:55, 11.98it/s]
#
#
# Creating HDF5 dataset:   1%|▏         | 53/3596 [00:04<05:01, 11.76it/s]
#
#
# Creating HDF5 dataset:   2%|▏         | 55/3596 [00:04<04:54, 12.03it/s]
#
#
# Creating HDF5 dataset:   2%|▏         |
#
#
# Creating HDF5 dataset:  37%|███▋      | 377/1027 [00:35<00:59, 10.89it/s]
#
#
# Creating HDF5 dataset:  37%|███▋      | 379/1027 [00:35<00:58, 11.02it/s]
#
#
# Creating HDF5 dataset:  37%|███▋      | 381/1027 [00:35<01:01, 10.42it/s]
#
#
# Creating HDF5 dataset:  37%|███▋      | 384/1027 [00:35<00:51, 12.40it/s]
#
#
# Creating HDF5 dataset:  38%|███▊      | 387/1027 [00:36<00:43, 14.76it/s]
#
#
# Creating HDF5 dataset:  38%|███▊      | 389/1027 [00:36<00:41, 15.38it/s]
#
#
# Creating HDF5 dataset:  38%|███▊      | 392/1027 [00:36<00:36, 17.28it/s]
#
#
# Creating HDF5 dataset:  38%|███▊      | 395/1027 [00:36<00:32, 19.18it/s]
#
#
# Creating HDF5 dataset:  39%|███▉      | 398/1027 [00:36<00:30, 20.51it/s]
#
#
# Creating HDF5 dataset:  39%|███▉      | 401/1027 [00:36<00:29, 21.25it/s]
#
#
# Creating HDF5 dataset:  39%|███▉      | 404/1027 [00:36<00:28, 21.84it/s]
#
#
# Creating HDF5 dataset:  40%|███▉      | 407/1027 [00:36<00:28, 22.11it/s]
#
#
# Creating HDF5 dataset:  40%|███▉      | 410/1027 [00:36<00:25, 23.73it/s]
#
#
# Creating HDF5 dataset:  40%|████      | 413/1027 [00:37<00:27, 22.60it/s]
#
#
# Creating HDF5 dataset:  41%|████      | 416/1027 [00:37<00:28, 21.10it/s]
#
#
# Creating HDF5 dataset:  41%|████      | 419/1027 [00:37<00:27, 22.08it/s]
#
#
# Creating HDF5 dataset:  41%|████      | 422/1027 [00:37<00:27, 22.15it/s]
#
#
# Creating HDF5 dataset:  41%|████▏     | 425/1027 [00:37<00:27, 21.71it/s]
#
#
# Creating HDF5 dataset:  42%|████▏     | 429/1027 [00:37<00:25, 23.81it/s]
#
#
# Creating HDF5 dataset:  42%|████▏     | 432/1027 [00:37<00:25, 23.30it/s]
#
#
# Creating HDF5 dataset:  42%|████▏     | 435/1027 [00:38<00:24, 24.52it/s]
#
#
# Creating HDF5 dataset:  43%|████▎     | 438/1027 [00:38<00:24, 24.47it/s]
#
#
# Creating HDF5 dataset:  43%|████▎     | 441/1027 [00:38<00:24, 24.31it/s]
#
#
# Creating HDF5 dataset:  43%|████▎     | 444/1027 [00:38<00:23, 25.18it/s]
#
#
# Creating HDF5 dataset:  44%|████▎     | 447/1027 [00:38<00:23, 24.59it/s]
#
#
# Creating HDF5 dataset:  44%|████▍     | 450/1027 [00:38<00:22, 25.73it/s]
#
#
# Creating HDF5 dataset:  44%|████▍     | 453/1027 [00:38<00:21, 26.46it/s]
#
#
# Creating HDF5 dataset:  44%|████▍     | 456/1027 [00:38<00:24, 23.50it/s]
#
#
# Creating HDF5 dataset:  45%|████▍     | 459/1027 [00:39<00:24, 23.66it/s]
#
#
# Creating HDF5 dataset:  45%|████▍     | 462/1027 [00:39<00:23, 24.22it/s]
#
#
# Creating HDF5 dataset:  45%|████▌     | 465/1027 [00:39<00:22, 24.74it/s]
#
#
# Creating HDF5 dataset:  46%|████▌     | 468/1027 [00:39<00:22, 24.86it/s]
#
#
# Creating HDF5 dataset:  46%|████▌     | 471/1027 [00:39<00:21, 25.61it/s]
#
#
# Creating HDF5 dataset:  46%|████▋     | 475/1027 [00:39<00:20, 27.31it/s]
#
#
# Creating HDF5 dataset:  47%|████▋     | 478/1027 [00:39<00:20, 26.29it/s]
#
#
# Creating HDF5 dataset:  47%|████▋     | 481/1027 [00:39<00:20, 26.02it/s]
#
#
# Creating HDF5 dataset:  47%|████▋     | 485/1027 [00:39<00:19, 27.93it/s]
#
#
# Creating HDF5 dataset:  48%|████▊     | 488/1027 [00:40<00:19, 27.12it/s]
#
#
# Creating HDF5 dataset:  48%|████▊     | 491/1027 [00:40<00:20, 26.15it/s]
#
#
# Creating HDF5 dataset:  48%|████▊     | 494/1027 [00:40<00:20, 26.61it/s]
#
#
# Creating HDF5 dataset:  48%|████▊     | 497/1027 [00:40<00:20, 25.35it/s]
#
#
# Creating HDF5 dataset:  49%|████▉     | 501/1027 [00:40<00:19, 26.31it/s]
#
#
# Creating HDF5 dataset:  49%|████▉     | 504/1027 [00:40<00:20, 25.75it/s]
#
#
# Creating HDF5 dataset:  49%|████▉     | 507/1027 [00:40<00:19, 26.85it/s]
#
#
# Creating HDF5 dataset:  50%|████▉     | 511/1027 [00:40<00:18, 27.55it/s]
#
#
# Creating HDF5 dataset:  50%|█████     | 515/1027 [00:41<00:17, 29.10it/s]
#
#
# Creating HDF5 dataset:  50%|█████     | 518/1027 [00:41<00:18, 27.58it/s]
#
#
# Creating HDF5 dataset:  51%|█████     | 522/1027 [00:41<00:17, 28.69it/s]
#
#
# Creating HDF5 dataset:  51%|█████     | 525/1027 [00:41<00:19, 25.29it/s]
#
#
# Creating HDF5 dataset:  51%|█████▏    | 528/1027 [00:41<00:20, 24.78it/s]
#
#
# Creating HDF5 dataset:  52%|█████▏    | 531/1027 [00:41<00:19, 25.42it/s]
#
#
# Creating HDF5 dataset:  52%|█████▏    | 534/1027 [00:41<00:18, 26.57it/s]
#
#
# Creating HDF5 dataset:  52%|█████▏    | 537/1027 [00:41<00:19, 25.02it/s]
#
#
# Creating HDF5 dataset:  53%|█████▎    | 540/1027 [00:42<00:20, 23.59it/s]
#
#
# Creating HDF5 dataset:  53%|█████▎    | 543/1027 [00:42<00:21, 22.93it/s]
#
#
# Creating HDF5 dataset:  53%|█████▎    | 546/1027 [00:42<00:21, 22.50it/s]
#
#
# Creating HDF5 dataset:  53%|█████▎    | 549/1027 [00:42<00:20, 23.49it/s]
#
#
# Creating HDF5 dataset:  54%|█████▎    | 552/1027 [00:42<00:19, 23.92it/s]
#
#
# Creating HDF5 dataset:  54%|█████▍    | 555/1027 [00:42<00:19, 24.20it/s]
#
#
# Creating HDF5 dataset:  54%|█████▍    | 558/1027 [00:42<00:18, 24.99it/s]
#
#
# Creating HDF5 dataset:  55%|█████▍    | 561/1027 [00:42<00:18, 25.39it/s]
#
#
# Creating HDF5 dataset:  55%|█████▌    | 565/1027 [00:43<00:17, 26.78it/s]
#
#
# Creating HDF5 dataset:  55%|█████▌    | 568/1027 [00:43<00:16, 27.32it/s]
#
#
# Creating HDF5 dataset:  56%|█████▌    | 571/1027 [00:43<00:17, 26.54it/s]
#
#
# Creating HDF5 dataset:  56%|█████▌    | 574/1027 [00:43<00:16, 26.83it/s]
#
#
# Creating HDF5 dataset:  56%|█████▌    | 577/1027 [00:43<00:17, 25.27it/s]
#
#
# Creating HDF5 dataset:  56%|█████▋    | 580/1027 [00:43<00:16, 26.36it/s]
#
#
# Creating HDF5 dataset:  57%|█████▋    | 583/1027 [00:43<00:17, 26.02it/s]
#
#
# Creating HDF5 dataset:  57%|█████▋    | 586/1027 [00:43<00:17, 25.11it/s]
#
#
# Creating HDF5 dataset:  57%|█████▋    | 589/1027 [00:44<00:16, 26.28it/s]
#
#
# Creating HDF5 dataset:  58%|█████▊    | 592/1027 [00:44<00:16, 26.32it/s]
#
#
# Creating HDF5 dataset:  58%|█████▊    | 595/1027 [00:44<00:15, 27.21it/s]
#
#
# Creating HDF5 dataset:  58%|█████▊    | 598/1027 [00:44<00:15, 27.70it/s]
#
#
# Creating HDF5 dataset:  59%|█████▊    | 601/1027 [00:44<00:15, 26.92it/s]
#
#
# Creating HDF5 dataset:  59%|█████▉    | 605/1027 [00:44<00:14, 28.42it/s]
#
#
# Creating HDF5 dataset:  59%|█████▉    | 608/1027 [00:44<00:16, 25.20it/s]
#
#
# Creating HDF5 dataset:  59%|█████▉    | 611/1027 [00:44<00:16, 25.76it/s]
#
#
# Creating HDF5 dataset:  60%|█████▉    | 614/1027 [00:44<00:16, 25.70it/s]
#
#
# Creating HDF5 dataset:  60%|██████    | 617/1027 [00:45<00:15, 25.73it/s]
#
#
# Creating HDF5 dataset:  60%|██████    | 620/1027 [00:45<00:16, 25.29it/s]
#
#
# Creating HDF5 dataset:  61%|██████    | 623/1027 [00:45<00:15, 25.46it/s]
#
#
# Creating HDF5 dataset:  61%|██████    | 626/1027 [00:45<00:15, 25.10it/s]
#
#
# Creating HDF5 dataset:  61%|██████    | 629/1027 [00:45<00:15, 25.07it/s]
#
#
# Creating HDF5 dataset:  62%|██████▏   | 632/1027 [00:45<00:16, 24.66it/s]
#
#
# Creating HDF5 dataset:  62%|██████▏   | 636/1027 [00:45<00:14, 26.94it/s]
#
#
# Creating HDF5 dataset:  62%|██████▏   | 639/1027 [00:45<00:15, 25.80it/s]
#
#
# Creating HDF5 dataset:  63%|██████▎   | 643/1027 [00:46<00:14, 27.00it/s]
#
#
# Creating HDF5 dataset:  63%|██████▎   | 647/1027 [00:46<00:14, 27.11it/s]
#
#
# Creating HDF5 dataset:  63%|██████▎   | 650/1027 [00:46<00:13, 27.18it/s]
#
#
# Creating HDF5 dataset:  64%|██████▎   | 654/1027 [00:46<00:13, 27.83it/s]
#
#
# Creating HDF5 dataset:  64%|██████▍   | 657/1027 [00:46<00:14, 25.77it/s]
#
#
# Creating HDF5 dataset:  64%|██████▍   | 661/1027 [00:46<00:13, 26.65it/s]
#
#
# Creating HDF5 dataset:  65%|██████▍   | 664/1027 [00:46<00:13, 26.99it/s]
#
#
# Creating HDF5 dataset:  65%|██████▍   | 667/1027 [00:46<00:13, 26.69it/s]
#
#
# Creating HDF5 dataset:  65%|██████▌   | 670/1027 [00:47<00:13, 27.09it/s]
#
#
# Creating HDF5 dataset:  66%|██████▌   | 673/1027 [00:47<00:15, 22.81it/s]
#
#
# Creating HDF5 dataset:  66%|██████▌   | 676/1027 [00:47<00:14, 24.40it/s]
#
#
# Creating HDF5 dataset:  66%|██████▌   | 679/1027 [00:47<00:14, 24.09it/s]
#
#
# Creating HDF5 dataset:  66%|██████▋   | 682/1027 [00:47<00:13, 24.96it/s]
#
#
# Creating HDF5 dataset:  67%|██████▋   | 685/1027 [00:47<00:13, 25.92it/s]
#
#
# Creating HDF5 dataset:  67%|██████▋   | 688/1027 [00:47<00:12, 26.84it/s]
#
#
# Creating HDF5 dataset:  67%|██████▋   | 691/1027 [00:47<00:13, 24.84it/s]
#
#
# Creating HDF5 dataset:  68%|██████▊   | 694/1027 [00:48<00:13, 24.36it/s]
#
#
# Creating HDF5 dataset:  68%|██████▊   | 697/1027 [00:48<00:13, 24.43it/s]
#
#
# Creating HDF5 dataset:  68%|██████▊   | 701/1027 [00:48<00:12, 26.00it/s]
#
#
# Creating HDF5 dataset:  69%|██████▊   | 704/1027 [00:48<00:12, 26.45it/s]
#
#
# Creating HDF5 dataset:  69%|██████▉   | 707/1027 [00:48<00:12, 26.62it/s]
# Creating HDF5 dataset:  69%|██████▉   | 711/1027 [00:48<00:11, 27.51it/s]
#
#
# Creating HDF5 dataset:  70%|██████▉   | 714/1027 [00:48<00:11, 28.18it/s]
#
#
# Creating HDF5 dataset:  70%|██████▉   | 717/1027 [00:48<00:10, 28.53it/s]
#
#
# Creating HDF5 dataset:  70%|███████   | 720/1027 [00:49<00:14, 21.23it/s]
#
#
# Creating HDF5 dataset:  70%|███████   | 723/1027 [00:49<00:14, 21.40it/s]
#
#
# Creating HDF5 dataset:  71%|███████   | 726/1027 [00:49<00:13, 21.77it/s]
#
#
# Creating HDF5 dataset:  71%|███████   | 729/1027 [00:49<00:12, 23.02it/s]
#
#
# Creating HDF5 dataset:  71%|███████▏  | 733/1027 [00:49<00:11, 25.11it/s]
#
#
# Creating HDF5 dataset:  72%|███████▏  | 736/1027 [00:49<00:11, 24.67it/s]
#
#
# Creating HDF5 dataset:  72%|███████▏  | 739/1027 [00:49<00:11, 25.52it/s]
#
#
# Creating HDF5 dataset:  72%|███████▏  | 742/1027 [00:49<00:11, 25.39it/s]
#
#
# Creating HDF5 dataset:  73%|███████▎  | 746/1027 [00:50<00:10, 27.38it/s]
#
#
# Creating HDF5 dataset:  73%|███████▎  | 750/1027 [00:50<00:09, 29.29it/s]
#
#
# Creating HDF5 dataset:  73%|███████▎  | 754/1027 [00:50<00:09, 29.65it/s]
#
#
# Creating HDF5 dataset:  74%|███████▍  | 758/1027 [00:50<00:09, 28.21it/s]
#
#
# Creating HDF5 dataset:  74%|███████▍  | 761/1027 [00:50<00:09, 27.70it/s]
#
#
# Creating HDF5 dataset:  74%|███████▍  | 765/1027 [00:50<00:08, 29.99it/s]
#
#
# Creating HDF5 dataset:  75%|███████▍  | 769/1027 [00:50<00:08, 29.77it/s]
#
#
# Creating HDF5 dataset:  75%|███████▌  | 773/1027 [00:50<00:08, 29.59it/s]
#
#
# Creating HDF5 dataset:  76%|███████▌  | 777/1027 [00:51<00:08, 28.14it/s]
#
#
# Creating HDF5 dataset:  76%|███████▌  | 781/1027 [00:51<00:08, 28.64it/s]
#
#
# Creating HDF5 dataset:  76%|███████▋  | 784/1027 [00:51<00:08, 27.99it/s]
#
#
# Creating HDF5 dataset:  77%|███████▋  | 787/1027 [00:51<00:08, 27.83it/s]
#
#
# Creating HDF5 dataset:  77%|███████▋  | 790/1027 [00:51<00:08, 26.86it/s]
#
#
# Creating HDF5 dataset:  77%|███████▋  | 793/1027 [00:51<00:09, 25.43it/s]
#
#
# Creating HDF5 dataset:  78%|███████▊  | 796/1027 [00:51<00:08, 25.77it/s]
#
#
# Creating HDF5 dataset:  78%|███████▊  | 799/1027 [00:51<00:09, 24.22it/s]
#
#
# Creating HDF5 dataset:  78%|███████▊  | 802/1027 [00:52<00:09, 23.20it/s]
#
#
# Creating HDF5 dataset:  78%|███████▊  | 805/1027 [00:52<00:15, 14.38it/s]
#
#
# Creating HDF5 dataset:  79%|███████▊  | 808/1027 [00:52<00:13, 15.95it/s]
#
#
# Creating HDF5 dataset:  79%|███████▉  | 811/1027 [00:52<00:11, 18.47it/s]
#
#
# Creating HDF5 dataset:  79%|███████▉  | 814/1027 [00:52<00:10, 20.83it/s]
#
#
# Creating HDF5 dataset:  80%|███████▉  | 817/1027 [00:52<00:09, 21.81it/s]
#
#
# Creating HDF5 dataset:  80%|███████▉  | 821/1027 [00:53<00:08, 24.35it/s]
#
#
# Creating HDF5 dataset:  80%|████████  | 824/1027 [00:53<00:08, 24.58it/s]
#
#
# Creating HDF5 dataset:  81%|████████  | 827/1027 [00:53<00:07, 25.65it/s]
#
#
# Creating HDF5 dataset:  81%|████████  | 830/1027 [00:53<00:07, 24.70it/s]
#
#
# Creating HDF5 dataset:  81%|████████  | 833/1027 [00:53<00:07, 25.28it/s]
#
#
# Creating HDF5 dataset:  81%|████████▏ | 836/1027 [00:53<00:07, 26.24it/s]
#
#
# Creating HDF5 dataset:  82%|████████▏ | 839/1027 [00:53<00:07, 25.42it/s]
#
#
# Creating HDF5 dataset:  82%|████████▏ | 842/1027 [00:53<00:07, 26.01it/s]
#
#
# Creating HDF5 dataset:  82%|████████▏ | 845/1027 [00:54<00:07, 25.94it/s]
#
#
# Creating HDF5 dataset:  83%|████████▎ | 848/1027 [00:54<00:07, 23.53it/s]
#
#
# Creating HDF5 dataset:  83%|████████▎ | 851/1027 [00:54<00:07, 22.67it/s]
#
#
# Creating HDF5 dataset:  83%|████████▎ | 854/1027 [00:54<00:07, 24.18it/s]
#
#
# Creating HDF5 dataset:  83%|████████▎ | 857/1027 [00:54<00:06, 24.63it/s]
#
#
# Creating HDF5 dataset:  84%|████████▎ | 860/1027 [00:54<00:06, 25.65it/s]
#
#
# Creating HDF5 dataset:  84%|████████▍ | 863/1027 [00:54<00:06, 23.95it/s]
#
#
# Creating HDF5 dataset:  84%|████████▍ | 867/1027 [00:54<00:05, 26.74it/s]
#
#
# Creating HDF5 dataset:  85%|████████▍ | 870/1027 [00:55<00:05, 26.61it/s]
#
#
# Creating HDF5 dataset:  85%|████████▌ | 873/1027 [00:55<00:06, 24.10it/s]
#
#
# Creating HDF5 dataset:  85%|████████▌ | 876/1027 [00:55<00:06, 23.58it/s]
#
#
# Creating HDF5 dataset:  86%|████████▌ | 879/1027 [00:55<00:06, 23.48it/s]
#
#
# Creating HDF5 dataset:  86%|████████▌ | 882/1027 [00:55<00:06, 23.48it/s]
#
#
# Creating HDF5 dataset:  86%|████████▌ | 885/1027 [00:55<00:05, 24.50it/s]
#
#
# Creating HDF5 dataset:  86%|████████▋ | 888/1027 [00:55<00:05, 25.09it/s]
#
#
# Creating HDF5 dataset:  87%|████████▋ | 891/1027 [00:55<00:05, 25.27it/s]
#
#
# Creating HDF5 dataset:  87%|████████▋ | 894/1027 [00:56<00:05, 24.26it/s]
#
#
# Creating HDF5 dataset:  87%|████████▋ | 897/1027 [00:56<00:05, 23.85it/s]
#
#
# Creating HDF5 dataset:  88%|████████▊ | 900/1027 [00:56<00:05, 24.13it/s]
#
#
# Creating HDF5 dataset:  88%|████████▊ | 903/1027 [00:56<00:05, 20.88it/s]
#
#
# Creating HDF5 dataset:  88%|████████▊ | 906/1027 [00:56<00:05, 22.18it/s]
#
#
# Creating HDF5 dataset:  89%|████████▊ | 909/1027 [00:56<00:05, 23.29it/s]
#
#
# Creating HDF5 dataset:  89%|████████▉ | 912/1027 [00:56<00:04, 23.93it/s]
#
#
# Creating HDF5 dataset:  89%|████████▉ | 915/1027 [00:56<00:04, 22.55it/s]
#
#
# Creating HDF5 dataset:  89%|████████▉ | 918/1027 [00:57<00:04, 23.62it/s]
#
#
# Creating HDF5 dataset:  90%|████████▉ | 921/1027 [00:57<00:04, 24.75it/s]
#
#
# Creating HDF5 dataset:  90%|████████▉ | 924/1027 [00:57<00:04, 24.64it/s]
#
#
# Creating HDF5 dataset:  90%|█████████ | 927/1027 [00:57<00:04, 24.47it/s]
#
#
# Creating HDF5 dataset:  91%|█████████ | 930/1027 [00:57<00:04, 23.20it/s]
#
#
# Creating HDF5 dataset:  91%|█████████ | 933/1027 [00:57<00:03, 23.53it/s]
#
#
# Creating HDF5 dataset:  91%|█████████ | 936/1027 [00:57<00:03, 23.97it/s]
#
#
# Creating HDF5 dataset:  91%|█████████▏| 939/1027 [00:57<00:03, 24.83it/s]
#
#
# Creating HDF5 dataset:  92%|█████████▏| 942/1027 [00:58<00:03, 26.07it/s]
#
#
# Creating HDF5 dataset:  92%|█████████▏| 945/1027 [00:58<00:03, 24.63it/s]
#
#
# Creating HDF5 dataset:  92%|█████████▏| 948/1027 [00:58<00:03, 25.41it/s]
#
#
# Creating HDF5 dataset:  93%|█████████▎| 951/1027 [00:58<00:03, 25.23it/s]
#
#
# Creating HDF5 dataset:  93%|█████████▎| 954/1027 [00:58<00:03, 24.22it/s]
#
#
# Creating HDF5 dataset:  93%|█████████▎| 957/1027 [00:58<00:02, 24.49it/s]
#
#
# Creating HDF5 dataset:  93%|█████████▎| 960/1027 [00:58<00:02, 24.52it/s]
#
#
# Creating HDF5 dataset:  94%|█████████▍| 963/1027 [00:58<00:02, 25.55it/s]
#
#
# Creating HDF5 dataset:  94%|█████████▍| 966/1027 [00:59<00:02, 24.54it/s]
#
#
# Creating HDF5 dataset:  94%|█████████▍| 969/1027 [00:59<00:02, 23.86it/s]
#
#
# Creating HDF5 dataset:  95%|█████████▍| 973/1027 [00:59<00:02, 25.83it/s]
#
#
# Creating HDF5 dataset:  95%|█████████▌| 976/1027 [00:59<00:01, 26.86it/s]
#
#
# Creating HDF5 dataset:  95%|█████████▌| 979/1027 [00:59<00:01, 27.32it/s]
#
#
# Creating HDF5 dataset:  96%|█████████▌| 982/1027 [00:59<00:01, 26.56it/s]
#
#
# Creating HDF5 dataset:  96%|█████████▌| 985/1027 [00:59<00:01, 27.29it/s]
#
#
# Creating HDF5 dataset:  96%|█████████▌| 988/1027 [00:59<00:01, 26.29it/s]
#
#
# Creating HDF5 dataset:  96%|█████████▋| 991/1027 [00:59<00:01, 25.42it/s]
#
#
# Creating HDF5 dataset:  97%|█████████▋| 994/1027 [01:00<00:01, 25.50it/s]
#
#
# Creating HDF5 dataset:  97%|█████████▋| 997/1027 [01:00<00:01, 26.13it/s]
#
#
# Creating HDF5 dataset:  97%|█████████▋| 1000/1027 [01:00<00:01, 26.49it/s]
#
#
# Creating HDF5 dataset:  98%|█████████▊| 1003/1027 [01:00<00:00, 24.86it/s]
#
#
# Creating HDF5 dataset:  98%|█████████▊| 1007/1027 [01:00<00:00, 26.13it/s]
#
#
# Creating HDF5 dataset:  98%|█████████▊| 1010/1027 [01:00<00:00, 26.85it/s]
#
#
# Creating HDF5 dataset:  99%|█████████▊| 1014/1027 [01:00<00:00, 28.33it/s]
#
#
# Creating HDF5 dataset:  99%|█████████▉| 1017/1027 [01:00<00:00, 27.63it/s]
#
#
# Creating HDF5 dataset:  99%|█████████▉| 1020/1027 [01:01<00:00, 27.20it/s]
#
#
# Creating HDF5 dataset: 100%|█████████▉| 1023/1027 [01:01<00:00, 24.97it/s]
#
#
# Creating HDF5 dataset: 100%|█████████▉| 1026/1027 [01:01<00:00, 25.45it/s]
#
#
# Creating HDF5 dataset: 100%|██████████| 1027/1027 [01:01<00:00, 16.74it/s]
